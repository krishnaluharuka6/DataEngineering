# %%
import pandas as pd

df = pd.read_csv("demo_data_100.csv")
print(df.to_string())
# Out:
#        Name   Age        City  Marks
# 0   Prakash  23.0      Butwal   65.0
# 1      Rina  21.0     Hetauda   65.0
# 2     Laxmi  20.0         NaN   85.0
# 3     Kamal   NaN      Dharan   70.0
# 4   Prakash  24.0     Pokhara    NaN
# 5     Nisha  22.0     Pokhara   80.0
# 6    Bikash  23.0  Biratnagar   60.0
# 7   Prakash   NaN     Hetauda   75.0
# 8     Laxmi  22.0   Kathmandu   60.0
# 9     Kamal  22.0      Dharan   75.0
# 10     Rina  20.0      Butwal   60.0
# 11    Laxmi  22.0   Kathmandu   85.0
# 12    Laxmi  24.0     Hetauda   80.0
# 13   Bikash   NaN         NaN    NaN
# 14     Maya  22.0      Butwal   75.0
# 15    Kamal  20.0         NaN    NaN
# 16     Sita  24.0  Biratnagar    NaN
# 17    Laxmi  21.0  Biratnagar    NaN
# 18     Maya   NaN     Pokhara   90.0
# 19     Sita  22.0         NaN   70.0
# 20    Kamal  20.0     Hetauda   60.0
# 21    Aarav  21.0      Dharan    NaN
# 22    Nisha  21.0      Butwal   60.0
# 23     Maya  23.0   Kathmandu    NaN
# ...

# %%
df.head()
# Out:
#       Name   Age     City  Marks
# 0  Prakash  23.0   Butwal   65.0
# 1     Rina  21.0  Hetauda   65.0
# 2    Laxmi  20.0      NaN   85.0
# 3    Kamal   NaN   Dharan   70.0
# 4  Prakash  24.0  Pokhara    NaN
